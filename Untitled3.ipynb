# %% [markdown]
# <a href="https://colab.research.google.com/github/aryann402/data-science/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Create the DataFrame
data = {
    "Student_ID": ["S001","S002","S003","S004","S005","S006","S007","S008","S009","S010"],
    "Name": ["Arjun Mehta","Divya Sharma","Karan Patel","Meera Nair","Sahil Gupta",
             "Anjali Singh","Rohan Verma","Pooja Yadav","Vivek Kumar","Nisha Agarwal"],
    "Age": [21,22,20,23,21,22,20,23,21,22],
    "City": ["Delhi","Mumbai","Pune","Chennai","Delhi","Jaipur","Mumbai","Chennai","Pune","Delhi"],
    "Department": ["CSE","ECE","CSE","MECH","ECE","CSE","MECH","CSE","ECE","MECH"],
    "Marks": [78,91,55,42,88,35,67,92,71,58],
    "Grade": ["B","A","C","D","A","F","B","A","B","C"],
    "Passed": [True,True,True,True,True,False,True,True,True,True]
}

df = pd.DataFrame(data)

# Display Shape
print("Shape of DataFrame:")
print(df.shape)

# Display Column Names
print("\nColumns:")
print(df.columns)

# Display Data Types
print("\nData Types:")
print(df.dtypes)

# Display First 5 Rows
print("\nHead (First 5 Rows):")
print(df.head(5))

# Display Last 3 Rows
print("\nTail (Last 3 Rows):")
print(df.tail(3))
