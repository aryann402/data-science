# %% [markdown]
# <a href="https://colab.research.google.com/github/aryann402/data-science/blob/main/Welcome_to_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
pd.read_csv("/content/drive/MyDrive/World Cup 2018 Dataset.csv")
# Out:
#             Team Group  Previous \nappearances  Previous \ntitles  \
# 0         Russia     A                    10.0                0.0
# 1   Saudi Arabia     A                     4.0                0.0
# 2          Egypt     A                     2.0                0.0
# 3        Uruguay     A                    12.0                2.0
# 4        Porugal     B                     6.0                0.0
# 5          Spain     B                    14.0                1.0
# 6        Morocco     B                     4.0                0.0
# 7           IRAN     B                     4.0                0.0
# 8         France     C                    14.0                1.0
# 9      Australia     C                     4.0                0.0
# 10          Peru     C                     4.0                0.0
# 11       Denmark     C                     4.0                0.0
# 12     Argentina     D                    16.0                2.0
# ...

# %%
import pandas as pd
dataframe = pd.read_csv("/content/drive/MyDrive/World Cup 2018 Dataset.csv")
dataframe
# Out:
#             Team Group  Previous \nappearances  Previous \ntitles  \
# 0         Russia     A                    10.0                0.0
# 1   Saudi Arabia     A                     4.0                0.0
# 2          Egypt     A                     2.0                0.0
# 3        Uruguay     A                    12.0                2.0
# 4        Porugal     B                     6.0                0.0
# 5          Spain     B                    14.0                1.0
# 6        Morocco     B                     4.0                0.0
# 7           IRAN     B                     4.0                0.0
# 8         France     C                    14.0                1.0
# 9      Australia     C                     4.0                0.0
# 10          Peru     C                     4.0                0.0
# 11       Denmark     C                     4.0                0.0
# 12     Argentina     D                    16.0                2.0
# ...

# %%
dataframe=pd.read_csv("/content/drive/MyDrive/World Cup 2018 Dataset.csv")
dataframe
# Out:
#             Team Group  Previous \nappearances  Previous \ntitles  \
# 0         Russia     A                    10.0                0.0
# 1   Saudi Arabia     A                     4.0                0.0
# 2          Egypt     A                     2.0                0.0
# 3        Uruguay     A                    12.0                2.0
# 4        Porugal     B                     6.0                0.0
# 5          Spain     B                    14.0                1.0
# 6        Morocco     B                     4.0                0.0
# 7           IRAN     B                     4.0                0.0
# 8         France     C                    14.0                1.0
# 9      Australia     C                     4.0                0.0
# 10          Peru     C                     4.0                0.0
# 11       Denmark     C                     4.0                0.0
# 12     Argentina     D                    16.0                2.0
# ...

# %%
dataframe.tail(10)
# Out:
#         Team Group  Previous \nappearances  Previous \ntitles  \
# 23     Korea     F                     9.0                0.0
# 24   Belgium     G                    12.0                0.0
# 25    Panama     G                     0.0                0.0
# 26   Tunisia     G                     4.0                0.0
# 27   England     G                    14.0                1.0
# 28    Poland     H                     7.0                0.0
# 29   Senegal     H                     1.0                0.0
# 30  Columbia     H                     5.0                0.0
# 31     Japan     H                     5.0                0.0
# 32       NaN   NaN                     NaN                NaN
#
#     Previous\n finals  Previous\n semifinals  Current \nFIFA rank  \
# 23                0.0                    1.0                 59.0
# 24                0.0                    1.0                  5.0
# 25                0.0                    0.0                 56.0
# ...

# %%
dataframe.head(20)
# Out:
#             Team Group  Previous \nappearances  Previous \ntitles  \
# 0         Russia     A                    10.0                0.0
# 1   Saudi Arabia     A                     4.0                0.0
# 2          Egypt     A                     2.0                0.0
# 3        Uruguay     A                    12.0                2.0
# 4        Porugal     B                     6.0                0.0
# 5          Spain     B                    14.0                1.0
# 6        Morocco     B                     4.0                0.0
# 7           IRAN     B                     4.0                0.0
# 8         France     C                    14.0                1.0
# 9      Australia     C                     4.0                0.0
# 10          Peru     C                     4.0                0.0
# 11       Denmark     C                     4.0                0.0
# 12     Argentina     D                    16.0                2.0
# ...

# %%
type(dataframe)
# Out:
# pandas.core.frame.DataFrame

# %%
dataframe.dtypes
# Out:
# Team                                       object
# Group                                      object
# Previous \nappearances                    float64
# Previous \ntitles                         float64
# Previous\n finals                         float64
# Previous\n semifinals                     float64
# Current \nFIFA rank                       float64
# First match \nagainst                      object
# Match index                               float64
# history with \nfirst opponent\n W-L       float64
# history with\n first opponent\n goals     float64
# Second match\n against                     object
# Match index.1                             float64
# history with\n second opponent\n W-L      float64
# history with\n second opponent\n goals    float64
# Third match\n against                      object
# Match index.2                             float64
# history with\n third opponent\n W-L       float64
# history with\n third opponent\n goals     float64
# ...

# %%
dataframe[["Team","Group"]]
# Out:
#             Team Group
# 0         Russia     A
# 1   Saudi Arabia     A
# 2          Egypt     A
# 3        Uruguay     A
# 4        Porugal     B
# 5          Spain     B
# 6        Morocco     B
# 7           IRAN     B
# 8         France     C
# 9      Australia     C
# 10          Peru     C
# 11       Denmark     C
# 12     Argentina     D
# 13       Iceland     D
# 14       Croatia     D
# 15       Nigeria     D
# 16        Brazil     E
# 17   Switzerland     E
# 18     Costarica     E
# 19        Serbia     E
# 20       Germany     F
# 21        Mexico     F
# 22        Sweden     F
# 23         Korea     F
# 24       Belgium     G
# 25        Panama     G
# 26       Tunisia     G
# 27       England     G
# 28        Poland     H
# 29       Senegal     H
# 30      Columbia     H
# 31         Japan     H
# 32           NaN   NaN

# %%
dataframe.shape
# Out:
# (33, 20)
